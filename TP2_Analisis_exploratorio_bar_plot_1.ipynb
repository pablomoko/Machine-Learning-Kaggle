# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

train_data = pd.read_parquet("/content/drive/MyDrive/TP2 - ORGANIZACIÓN DE DATOS/dataset_v2/train.parq", engine="pyarrow")
train_data.dropna(inplace=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Distribución de labels (0 y 1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.countplot(data=train_data, x='label', palette='coolwarm')
plt.title("Distribución de label (0 y 1)")
plt.xlabel("Label")
plt.ylabel("Frecuencia")
plt.show()
